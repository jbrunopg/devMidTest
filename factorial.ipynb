# %%
import tkinter as tk

def calculate_factorial():
    try:
        number = int(entry.get())
        if number < 0:
            result_label.config(text="O número deve ser positivo.")
        else:
            result = factorial(number)
            result_label.config(text=f"O fatorial de {number} é {result}.")
    except ValueError:
        result_label.config(text="Por favor, digite um número inteiro.")

# Configuração básica da janela
window = tk.Tk()
window.title("Cálculo de Fatorial")
window.geometry("300x200")

# Elementos da interface
entry_label = tk.Label(window, text="Digite um número inteiro:")
entry_label.pack(pady=10)
entry = tk.Entry(window)
entry.pack()
calculate_button = tk.Button(window, text="Calcular Fatorial", command=calculate_factorial)
calculate_button.pack(pady=5)
result_label = tk.Label(window, text="")
result_label.pack(pady=10)

# Iniciar a aplicação
window.mainloop()
